# %%
import time
import json
import os
from typing import List, Dict, Any, Tuple
from dotenv import load_dotenv
from openai import OpenAI

# Load API key from .env file
load_dotenv()
client = OpenAI(
    base_url = "https://openai.vocareum.com/v1",
    api_key=os.getenv("OPENAI_API_KEY"))

# %%
class Task:
    def __init__(self, name, complexity, priority, deadline="normal"):
        self.name = name
        self.complexity = complexity  # 1-10
        self.priority = priority      # 1-10
        self.deadline = deadline      # "urgent", "normal", "flexible"
        self.completed = False
    
    def __str__(self):
        return f"Task: {self.name} (Complexity: {self.complexity}, Priority: {self.priority}, Deadline: {self.deadline})"

class SimpleAgent:
    def __init__(self, name, specialty):
        self.name = name
        self.specialty = specialty  # "high_priority" or "low_complexity"
    
    def decide_action(self, tasks):
        """Determines what action to take based on available tasks."""
        if not tasks:
            return None, "No tasks available"
        
        if self.specialty == "high_priority":
            # This agent focuses on high priority tasks
            best_task = max(tasks, key=lambda t: t.priority)
            return best_task, f"Selected highest priority task: {best_task.name}"
        
        elif self.specialty == "low_complexity":
            # This agent focuses on easiest tasks first
            best_task = min(tasks, key=lambda t: t.complexity)
            return best_task, f"Selected lowest complexity task: {best_task.name}"
    
    def process_task(self, task):
        """Process the selected task."""
        if task:
            print(f" - Agent {self.name} processing {task.name}...")
            time.sleep(0.5)
            task.completed = True
            return f"Completed task: {task.name}"
        return "No task to process"

class LLMAgent:
    """An agent that uses OpenAI's LLM to make strategic decisions."""
    
    def __init__(self, name):
        self.name = name
    
    def format_tasks_for_prompt(self, tasks):
        """Format the tasks into a readable string for the prompt."""
        task_details = []
        for i, task in enumerate(tasks):
            task_details.append(f"Task {i+1}: {task.name}")
            task_details.append(f"  - Priority: {task.priority}/10")
            task_details.append(f"  - Complexity: {task.complexity}/10")
            task_details.append(f"  - Deadline: {task.deadline}")
        
        return "\n".join(task_details)
    
    def decide_strategy(self, tasks):
        """Use OpenAI to decide between priority or efficiency strategy."""
        if not tasks:
            return "none", "No tasks available", "No strategy needed"
        
        # Create a prompt for the LLM
        prompt = f"""
        I have {len(tasks)} tasks to complete. I need to decide whether to prioritize tasks based on their priority level (PRIORITY strategy) or handle them based on their complexity (EFFICIENCY strategy, doing easiest tasks first).

        Here are the current tasks:
        {self.format_tasks_for_prompt(tasks)}

        As a task management expert, analyze this situation and decide whether I should use the PRIORITY strategy or the EFFICIENCY strategy.

        Your response must be in JSON format with these fields:
        {{
            "reasoning": "Your detailed analysis of the situation",
            "decision": "priority OR efficiency",
            "explanation": "A concise explanation of your recommendation"
        }}
        """
        
        try:
            # Make API call to OpenAI
            response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are a workflow management expert that helps decide the best strategy for handling tasks."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.2,  # Lower temperature for more consistent decision-making
            )
            
            # Extract the response text
            result_text = response.choices[0].message.content
            
            try:
                # Parse the JSON response
                result = json.loads(result_text)
                return result["decision"], result["reasoning"], result["explanation"]
            except (json.JSONDecodeError, KeyError):
                # If JSON parsing fails, extract what we can from the text
                if "priority" in result_text.lower():
                    return "priority", "LLM recommended priority approach", result_text
                else:
                    return "efficiency", "LLM recommended efficiency approach", result_text
                
        except Exception as e:
            # Handle API errors gracefully
            print(f"Error calling OpenAI API: {e}")
            # Default to priority if there's an error
            return "priority", f"API error: {str(e)}", "Defaulting to priority strategy due to API error"

def deterministic_workflow(tasks):
    """A deterministic workflow with fixed rules."""
    print("\n==== DETERMINISTIC WORKFLOW ====")
    print("This workflow uses hardcoded rules to decide between priority and efficiency.")
    
    # Create agents
    priority_agent = SimpleAgent("Priority Handler", "high_priority")
    complexity_agent = SimpleAgent("Efficiency Expert", "low_complexity")
    
    # Create a copy of tasks to work with
    remaining_tasks = tasks.copy()
    
    step = 1
    while remaining_tasks:
        print(f"\nStep {step}: Applying fixed decision rules")
        
        # Display current task status
        print(f"Current task status: {len(remaining_tasks)} tasks remaining")
        for i, task in enumerate(remaining_tasks):
            print(f"  {i+1}. {task}")
        
        # Hard-coded decision logic
        urgent_tasks = sum(1 for t in remaining_tasks if t.deadline == "urgent")
        high_priority_tasks = sum(1 for t in remaining_tasks if t.priority >= 8)
        
        # Fixed rule-based decision
        if urgent_tasks > 0 or high_priority_tasks > 0:
            print("\nFixed rule: Found urgent or high-priority tasks -> Using PRIORITY strategy")
            active_agent = priority_agent
        else:
            print("\nFixed rule: No urgent or high-priority tasks -> Using EFFICIENCY strategy")
            active_agent = complexity_agent
        
        # The specialist agent selects and processes a task
        chosen_task, selection_reasoning = active_agent.decide_action(remaining_tasks)
        print(f"Agent reasoning: {selection_reasoning}")
        
        result = active_agent.process_task(chosen_task)
        print(f"Result: {result}")
        
        # Update remaining tasks
        remaining_tasks = [t for t in remaining_tasks if not t.completed]
        
        step += 1
    
    print("\nWorkflow completed. All tasks processed through deterministic rules.")
    return tasks

def llm_agentic_workflow(tasks):
    """An agentic workflow where an LLM decides the strategy."""
    print("\n==== LLM-BASED AGENTIC WORKFLOW ====")
    print("This workflow uses an OpenAI LLM to reason about strategy in natural language.")
    
    # Create agents
    strategy_agent = LLMAgent("Strategy Advisor")
    priority_agent = SimpleAgent("Priority Handler", "high_priority")
    complexity_agent = SimpleAgent("Efficiency Expert", "low_complexity")
    
    # Create a copy of tasks to work with
    remaining_tasks = tasks.copy()
    
    step = 1
    while remaining_tasks:
        print(f"\nStep {step}: LLM analyzing situation and determining strategy")
        
        # Display current task status
        print(f"Current task status: {len(remaining_tasks)} tasks remaining")
        for i, task in enumerate(remaining_tasks):
            print(f"  {i+1}. {task}")
        
        # LLM agent reasons about the strategy
        strategy, reasoning, explanation = strategy_agent.decide_strategy(remaining_tasks)
        
        print("\nLLM Reasoning:")
        print(reasoning)
        print("\nLLM Recommendation:")
        print(explanation)
        
        # Execute the strategy using the appropriate specialist agent
        if strategy == "priority":
            print("\nExecuting PRIORITY strategy:")
            active_agent = priority_agent
        else:  # efficiency
            print("\nExecuting EFFICIENCY strategy:")
            active_agent = complexity_agent
        
        # The specialist agent selects and processes a task
        chosen_task, selection_reasoning = active_agent.decide_action(remaining_tasks)
        print(f"Agent reasoning: {selection_reasoning}")
        
        result = active_agent.process_task(chosen_task)
        print(f"Result: {result}")
        
        # Update remaining tasks
        remaining_tasks = [t for t in remaining_tasks if not t.completed]
        
        step += 1
    
    print("\nWorkflow completed. All tasks processed through LLM-guided decision-making.")
    return tasks

def main():
    # Create some sample tasks with varied properties
    tasks = [
        Task("Data cleaning", 3, 4, "normal"),
        Task("Machine learning model training", 8, 7, "flexible"),
        Task("Report generation", 4, 9, "urgent"),
        Task("Database backup", 2, 10, "urgent"),
        Task("Code review", 5, 6, "normal"),
        Task("Client presentation", 6, 9, "urgent"),
        Task("Documentation update", 2, 3, "flexible")
    ]
    
    # Create copies for each workflow
    deterministic_tasks = [Task(t.name, t.complexity, t.priority, t.deadline) for t in tasks]
    llm_agentic_tasks = [Task(t.name, t.complexity, t.priority, t.deadline) for t in tasks]
    
    # Check if API key is available
    if not os.getenv("OPENAI_API_KEY"):
        print("\n⚠️  Warning: OPENAI_API_KEY not found in .env file")
        print("Create a .env file with your OpenAI API key to make actual API calls.")
        print("Example .env file content: OPENAI_API_KEY=your-key-here\n")
    
    # Run both workflows to compare
    deterministic_workflow(deterministic_tasks)
    llm_agentic_workflow(llm_agentic_tasks)
    
    print("\n==== COMPARISON ====")
    print("Deterministic workflow:")
    print("- Used simple if/else rules with fixed thresholds")
    print("- Limited flexibility with hardcoded decision boundaries")
    print("- Cannot consider nuanced context or multiple factors simultaneously")
    print("- Logic changes require code modifications")
    print("\nLLM-based agentic workflow:")
    print("- Used natural language reasoning about the specific situation")
    print("- Considered multiple interrelated factors simultaneously")
    print("- Provided detailed reasoning and explanation for decisions")
    print("- Can adapt to new types of inputs without code changes")
    print("- Same simple code can handle increasingly complex decisions")

if __name__ == "__main__":
    main()
# Out:
# ==== DETERMINISTIC WORKFLOW ====
# This workflow uses hardcoded rules to decide between priority and efficiency.
#
# Step 1: Applying fixed decision rules
# Current task status: 7 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Report generation (Complexity: 4, Priority: 9, Deadline: urgent)
#   4. Task: Database backup (Complexity: 2, Priority: 10, Deadline: urgent)
#   5. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   6. Task: Client presentation (Complexity: 6, Priority: 9, Deadline: urgent)
#   7. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# Fixed rule: Found urgent or high-priority tasks -> Using PRIORITY strategy
# Agent reasoning: Selected highest priority task: Database backup
#  - Agent Priority Handler processing Database backup...
# Result: Completed task: Database backup
#
# Step 2: Applying fixed decision rules
# Current task status: 6 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Report generation (Complexity: 4, Priority: 9, Deadline: urgent)
#   4. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   5. Task: Client presentation (Complexity: 6, Priority: 9, Deadline: urgent)
#   6. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# Fixed rule: Found urgent or high-priority tasks -> Using PRIORITY strategy
# Agent reasoning: Selected highest priority task: Report generation
#  - Agent Priority Handler processing Report generation...
# Result: Completed task: Report generation
#
# Step 3: Applying fixed decision rules
# Current task status: 5 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   4. Task: Client presentation (Complexity: 6, Priority: 9, Deadline: urgent)
#   5. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# Fixed rule: Found urgent or high-priority tasks -> Using PRIORITY strategy
# Agent reasoning: Selected highest priority task: Client presentation
#  - Agent Priority Handler processing Client presentation...
# Result: Completed task: Client presentation
#
# Step 4: Applying fixed decision rules
# Current task status: 4 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   4. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# Fixed rule: No urgent or high-priority tasks -> Using EFFICIENCY strategy
# Agent reasoning: Selected lowest complexity task: Documentation update
#  - Agent Efficiency Expert processing Documentation update...
# Result: Completed task: Documentation update
#
# Step 5: Applying fixed decision rules
# Current task status: 3 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#
# Fixed rule: No urgent or high-priority tasks -> Using EFFICIENCY strategy
# Agent reasoning: Selected lowest complexity task: Data cleaning
#  - Agent Efficiency Expert processing Data cleaning...
# Result: Completed task: Data cleaning
#
# Step 6: Applying fixed decision rules
# Current task status: 2 tasks remaining
#   1. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   2. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#
# Fixed rule: No urgent or high-priority tasks -> Using EFFICIENCY strategy
# Agent reasoning: Selected lowest complexity task: Code review
#  - Agent Efficiency Expert processing Code review...
# Result: Completed task: Code review
#
# Step 7: Applying fixed decision rules
# Current task status: 1 tasks remaining
#   1. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#
# Fixed rule: No urgent or high-priority tasks -> Using EFFICIENCY strategy
# Agent reasoning: Selected lowest complexity task: Machine learning model training
#  - Agent Efficiency Expert processing Machine learning model training...
# Result: Completed task: Machine learning model training
#
# Workflow completed. All tasks processed through deterministic rules.
#
# ==== LLM-BASED AGENTIC WORKFLOW ====
# This workflow uses an OpenAI LLM to reason about strategy in natural language.
#
# Step 1: LLM analyzing situation and determining strategy
# Current task status: 7 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Report generation (Complexity: 4, Priority: 9, Deadline: urgent)
#   4. Task: Database backup (Complexity: 2, Priority: 10, Deadline: urgent)
#   5. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   6. Task: Client presentation (Complexity: 6, Priority: 9, Deadline: urgent)
#   7. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# LLM Reasoning:
# LLM recommended priority approach
#
# LLM Recommendation:
# ```json
# {
#     "reasoning": "Based on the provided tasks, it is recommended to use the PRIORITY strategy. The tasks vary in priority levels and deadlines, with some being urgent and others having flexible deadlines. Prioritizing tasks based on their importance and urgency will ensure that critical tasks are completed on time.",
#     "decision": "priority",
#     "explanation": "By focusing on tasks with higher priority levels and urgent deadlines first, you can ensure that critical deliverables are completed in a timely manner, meeting the overall project objectives effectively."
# }
# ```
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Database backup
#  - Agent Priority Handler processing Database backup...
# Result: Completed task: Database backup
#
# Step 2: LLM analyzing situation and determining strategy
# Current task status: 6 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Report generation (Complexity: 4, Priority: 9, Deadline: urgent)
#   4. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   5. Task: Client presentation (Complexity: 6, Priority: 9, Deadline: urgent)
#   6. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# LLM Reasoning:
# LLM recommended priority approach
#
# LLM Recommendation:
# ```json
# {
#     "reasoning": "Based on the provided tasks, it is recommended to use the PRIORITY strategy. This is because there are tasks with urgent deadlines and high priority levels that need immediate attention to ensure timely completion.",
#     "decision": "priority",
#     "explanation": "Prioritizing tasks based on their urgency and importance will help in meeting deadlines and addressing critical needs first, ensuring efficient task management in this scenario."
# }
# ```
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Report generation
#  - Agent Priority Handler processing Report generation...
# Result: Completed task: Report generation
#
# Step 3: LLM analyzing situation and determining strategy
# Current task status: 5 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   4. Task: Client presentation (Complexity: 6, Priority: 9, Deadline: urgent)
#   5. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# LLM Reasoning:
# LLM recommended priority approach
#
# LLM Recommendation:
# ```json
# {
#     "reasoning": "Based on the provided tasks and their attributes, it is recommended to use the PRIORITY strategy to manage the tasks effectively.",
#     "decision": "priority",
#     "explanation": "Prioritizing tasks based on their priority levels will ensure that urgent tasks with high priority are addressed first, meeting deadlines and critical client needs. This approach aligns with the urgency and importance of the tasks at hand, leading to better task management outcomes."
# }
# ```
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Client presentation
#  - Agent Priority Handler processing Client presentation...
# Result: Completed task: Client presentation
#
# Step 4: LLM analyzing situation and determining strategy
# Current task status: 4 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Machine learning model training (Complexity: 8, Priority: 7, Deadline: flexible)
#   3. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   4. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# LLM Reasoning:
# LLM recommended priority approach
#
# LLM Recommendation:
# ```json
# {
#     "reasoning": "In this situation, considering the tasks' priority levels, it seems that the PRIORITY strategy might be more suitable. Task 2 (Machine learning model training) has the highest priority level and Task 1 (Data cleaning) has the lowest priority level. If meeting deadlines and importance are key factors, prioritizing tasks based on their priority levels would ensure that critical tasks are addressed first.",
#     "decision": "priority",
#     "explanation": "I recommend using the PRIORITY strategy to ensure that tasks are tackled in order of their priority levels, focusing on the most important tasks first to meet deadlines and address critical aspects of the project."
# }
# ```
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Machine learning model training
#  - Agent Priority Handler processing Machine learning model training...
# Result: Completed task: Machine learning model training
#
# Step 5: LLM analyzing situation and determining strategy
# Current task status: 3 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Code review (Complexity: 5, Priority: 6, Deadline: normal)
#   3. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# LLM Reasoning:
# LLM recommended priority approach
#
# LLM Recommendation:
# ```json
# {
#     "reasoning": "Based on the provided information, the tasks have varying levels of priority and complexity. Task 2 (Code review) has the highest priority level and moderate complexity, while Task 3 (Documentation update) has the lowest priority level and complexity. Task 1 (Data cleaning) falls in between in terms of priority and complexity. Considering the deadlines are normal for all tasks, prioritizing based on complexity may lead to quicker completion of tasks with lower complexity, but it may not align with the priority levels set for each task.",
#     "decision": "priority",
#     "explanation": "I recommend using the PRIORITY strategy to ensure that tasks are completed in alignment with their assigned priority levels. This approach helps in meeting the overall goals and requirements of the project by addressing the most critical tasks first, even if they are not the easiest ones."
# }
# ```
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Code review
#  - Agent Priority Handler processing Code review...
# Result: Completed task: Code review
#
# Step 6: LLM analyzing situation and determining strategy
# Current task status: 2 tasks remaining
#   1. Task: Data cleaning (Complexity: 3, Priority: 4, Deadline: normal)
#   2. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
#
# LLM Reasoning:
# LLM recommended priority approach
#
# LLM Recommendation:
# ```json
# {
#     "reasoning": "In this scenario, considering the tasks' priority levels and complexities, it is more beneficial to use the EFFICIENCY strategy.",
#     "decision": "efficiency",
#     "explanation": "The EFFICIENCY strategy suggests completing tasks based on their complexity, starting with the easiest ones. Task 2, Documentation update, has a lower complexity level compared to Task 1, Data cleaning. Since both tasks have relatively low priority levels and no urgent deadlines, focusing on efficiency by tackling the easier task first can lead to quicker progress and a sense of accomplishment. This approach can help maintain motivation and momentum for completing the tasks efficiently."
# }
# ```
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Data cleaning
#  - Agent Priority Handler processing Data cleaning...
# Result: Completed task: Data cleaning
#
# Step 7: LLM analyzing situation and determining strategy
# Current task status: 1 tasks remaining
#   1. Task: Documentation update (Complexity: 2, Priority: 3, Deadline: flexible)
# Error calling OpenAI API: 'NoneType' object is not subscriptable
#
# LLM Reasoning:
# API error: 'NoneType' object is not subscriptable
#
# LLM Recommendation:
# Defaulting to priority strategy due to API error
#
# Executing PRIORITY strategy:
# Agent reasoning: Selected highest priority task: Documentation update
#  - Agent Priority Handler processing Documentation update...
# Result: Completed task: Documentation update
#
# Workflow completed. All tasks processed through LLM-guided decision-making.
#
# ==== COMPARISON ====
# Deterministic workflow:
# - Used simple if/else rules with fixed thresholds
# - Limited flexibility with hardcoded decision boundaries
# - Cannot consider nuanced context or multiple factors simultaneously
# - Logic changes require code modifications
#
# LLM-based agentic workflow:
# - Used natural language reasoning about the specific situation
# - Considered multiple interrelated factors simultaneously
# - Provided detailed reasoning and explanation for decisions
# - Can adapt to new types of inputs without code changes
# - Same simple code can handle increasingly complex decisions

# %%
import time

class Task:
    def __init__(self, name, complexity, priority):
        self.name = name
        self.complexity = complexity  # 1-10
        self.priority = priority      # 1-10
        self.completed = False
    
    def __str__(self):
        return f"Task: {self.name} (Complexity: {self.complexity}, Priority: {self.priority})"

def deterministic_workflow(tasks):
    """A deterministic workflow that processes tasks in a fixed sequence."""
    print("\n==== DETERMINISTIC WORKFLOW ====")
    print("This workflow follows a predefined sequence of steps regardless of context.")
    
    # Steps are hardcoded and always executed in the same order
    print("\nStep 1: Sort tasks by name")
    sorted_tasks = sorted(tasks, key=lambda t: t.name)
    for task in sorted_tasks:
        print(f" - {task}")
    
    print("\nStep 2: Process all tasks with complexity < 5")
    for task in sorted_tasks:
        if task.complexity < 5:
            print(f" - Processing {task.name}...")
            time.sleep(0.5)
            task.completed = True
    
    print("\nStep 3: Process remaining tasks")
    for task in sorted_tasks:
        if not task.completed:
            print(f" - Processing {task.name}...")
            time.sleep(0.5)
            task.completed = True
    
    print("\nWorkflow completed. All tasks processed in predetermined sequence.")
    return tasks

class SimpleAgent:
    def __init__(self, name, specialty):
        self.name = name
        self.specialty = specialty  # "high_priority" or "low_complexity"
    
    def decide_action(self, tasks):
        """Determines what action to take based on available tasks."""
        if not tasks:
            return None, "No tasks available"
        
        if self.specialty == "high_priority":
            # This agent focuses on high priority tasks
            best_task = max(tasks, key=lambda t: t.priority)
            return best_task, f"Selected highest priority task: {best_task.name}"
        
        elif self.specialty == "low_complexity":
            # This agent focuses on easiest tasks first
            best_task = min(tasks, key=lambda t: t.complexity)
            return best_task, f"Selected lowest complexity task: {best_task.name}"
    
    def process_task(self, task):
        """Process the selected task."""
        if task:
            print(f" - Agent {self.name} processing {task.name}...")
            time.sleep(0.5)
            task.completed = True
            return f"Completed task: {task.name}"
        return "No task to process"

def agentic_workflow(tasks):
    """An agentic workflow where agents dynamically decide what to do next."""
    print("\n==== AGENTIC WORKFLOW ====")
    print("This workflow uses agents that reason about what to do at each step.")
    
    # Create two simple agents with different specialties
    priority_agent = SimpleAgent("Priority Handler", "high_priority")
    complexity_agent = SimpleAgent("Efficiency Expert", "low_complexity")
    
    # Create a copy of tasks to work with
    remaining_tasks = tasks.copy()
    
    step = 1
    while remaining_tasks:
        print(f"\nStep {step}: Agents analyze current situation and decide what to do")
        
        # Agents assess the situation and decide what to do next
        print(f"Current task status: {len(remaining_tasks)} tasks remaining")
        
        # Agents reason about which tasks to tackle next
        priority_task, priority_reasoning = priority_agent.decide_action(remaining_tasks)
        complexity_task, complexity_reasoning = complexity_agent.decide_action(remaining_tasks)
        
        print(f"Priority Agent reasoning: {priority_reasoning}")
        print(f"Efficiency Agent reasoning: {complexity_reasoning}")
        
        # Determine which agent's approach is better for the current situation
        if len(remaining_tasks) > 3:
            print("System decision: Many tasks remaining, focusing on efficiency")
            active_agent = complexity_agent
            chosen_task = complexity_task
        else:
            print("System decision: Few tasks remaining, focusing on priority")
            active_agent = priority_agent
            chosen_task = priority_task
        
        # Execute the chosen action
        result = active_agent.process_task(chosen_task)
        print(f"Result: {result}")
        
        # Update remaining tasks
        remaining_tasks = [t for t in remaining_tasks if not t.completed]
        
        step += 1
    
    print("\nWorkflow completed. All tasks processed through dynamic decision-making.")
    return tasks


def main():
    # Create some sample tasks
    tasks = [
        Task("Data cleaning", 3, 4),
        Task("Machine learning model training", 8, 7),
        Task("Report generation", 4, 9),
        Task("Database backup", 2, 10),
        Task("Code review", 5, 6)
    ]
    
    # Make copies for each workflow
    deterministic_tasks = [Task(t.name, t.complexity, t.priority) for t in tasks]
    agentic_tasks = [Task(t.name, t.complexity, t.priority) for t in tasks]
    
    # Run both workflows
    deterministic_workflow(deterministic_tasks)
    agentic_workflow(agentic_tasks)
    
    print("\n==== COMPARISON ====")
    print("Deterministic workflow: Followed fixed steps regardless of task attributes")
    print("Agentic workflow: Dynamically reasoned about each step based on remaining tasks")

if __name__ == "__main__":
    main()
# Out:
# ==== DETERMINISTIC WORKFLOW ====
# This workflow follows a predefined sequence of steps regardless of context.
#
# Step 1: Sort tasks by name
#  - Task: Code review (Complexity: 5, Priority: 6)
#  - Task: Data cleaning (Complexity: 3, Priority: 4)
#  - Task: Database backup (Complexity: 2, Priority: 10)
#  - Task: Machine learning model training (Complexity: 8, Priority: 7)
#  - Task: Report generation (Complexity: 4, Priority: 9)
#
# Step 2: Process all tasks with complexity < 5
#  - Processing Data cleaning...
#  - Processing Database backup...
#  - Processing Report generation...
#
# Step 3: Process remaining tasks
#  - Processing Code review...
#  - Processing Machine learning model training...
#
# Workflow completed. All tasks processed in predetermined sequence.
#
# ==== AGENTIC WORKFLOW ====
# This workflow uses agents that reason about what to do at each step.
#
# Step 1: Agents analyze current situation and decide what to do
# Current task status: 5 tasks remaining
# Priority Agent reasoning: Selected highest priority task: Database backup
# Efficiency Agent reasoning: Selected lowest complexity task: Database backup
# System decision: Many tasks remaining, focusing on efficiency
#  - Agent Efficiency Expert processing Database backup...
# Result: Completed task: Database backup
#
# Step 2: Agents analyze current situation and decide what to do
# Current task status: 4 tasks remaining
# Priority Agent reasoning: Selected highest priority task: Report generation
# Efficiency Agent reasoning: Selected lowest complexity task: Data cleaning
# System decision: Many tasks remaining, focusing on efficiency
#  - Agent Efficiency Expert processing Data cleaning...
# Result: Completed task: Data cleaning
#
# Step 3: Agents analyze current situation and decide what to do
# Current task status: 3 tasks remaining
# Priority Agent reasoning: Selected highest priority task: Report generation
# Efficiency Agent reasoning: Selected lowest complexity task: Report generation
# System decision: Few tasks remaining, focusing on priority
#  - Agent Priority Handler processing Report generation...
# Result: Completed task: Report generation
#
# Step 4: Agents analyze current situation and decide what to do
# Current task status: 2 tasks remaining
# Priority Agent reasoning: Selected highest priority task: Machine learning model training
# Efficiency Agent reasoning: Selected lowest complexity task: Code review
# System decision: Few tasks remaining, focusing on priority
#  - Agent Priority Handler processing Machine learning model training...
# Result: Completed task: Machine learning model training
#
# Step 5: Agents analyze current situation and decide what to do
# Current task status: 1 tasks remaining
# Priority Agent reasoning: Selected highest priority task: Code review
# Efficiency Agent reasoning: Selected lowest complexity task: Code review
# System decision: Few tasks remaining, focusing on priority
#  - Agent Priority Handler processing Code review...
# Result: Completed task: Code review
#
# Workflow completed. All tasks processed through dynamic decision-making.
#
# ==== COMPARISON ====
# Deterministic workflow: Followed fixed steps regardless of task attributes
# Agentic workflow: Dynamically reasoned about each step based on remaining tasks
