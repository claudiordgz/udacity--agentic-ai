# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables and initialize OpenAI client
load_dotenv()
client = OpenAI(
    base_url = "https://openai.vocareum.com/v1",
    api_key=os.getenv("OPENAI_API_KEY"))

def call_openai(system_prompt, user_prompt, temp, model="gpt-3.5-turbo"):
    """Simple wrapper for OpenAI API calls"""
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=temp
    )
    return response.choices[0].message.content

def researcher_agent(topic):
    """Researcher agent that gathers information on a topic"""
    system_prompt = """You are a research specialist who provides structured information.
    Always format your response with these exact headings:
    # OVERVIEW
    # KEY POINTS
    # DETAILS
    """
    
    user_prompt = f"Research this topic thoroughly: {topic}"
    
    print(f"Researcher agent working on: {topic}")
    return call_openai(system_prompt, user_prompt, temp = 0.7)

def writer_agent(topic, research_results):
    """Writer agent that creates content based on research"""
    system_prompt = """You are a content writer who creates engaging material from research.
    Create a well-structured article with a clear introduction, body, and conclusion.
    """
    
    user_prompt = f"""Write an engaging article about {topic} using this research:
    
    {research_results}
    """
    
    print(f"Writer agent creating content for: {topic}")
    return call_openai(system_prompt, user_prompt, temp = 0.3)

def run_simple_chain(topic):
    """Run a minimal agent chain: Researcher → Writer"""
    print(f"\nStarting simple agent chain for: '{topic}'")
    
    # Step 1: Get research from researcher agent
    research = researcher_agent(topic)
    print("\nResearch complete!")
    
    # Step 2: Pass research to writer agent
    content = writer_agent(topic, research)
    print("\nContent creation complete!")
    
    # Print results
    print("\n===== RESEARCH OUTPUT =====")
    print(research)
    
    print("\n===== FINAL CONTENT =====")
    print(content)
    
    return {"research": research, "content": content}

# Run the example
if __name__ == "__main__":
    topic = "What are the latest breakthroughts in implementing AI in big corporations?"
    results = run_simple_chain(topic)
# Out:
# Starting simple agent chain for: 'What are the latest breakthroughts in implementing AI in big corporations?'
# Researcher agent working on: What are the latest breakthroughts in implementing AI in big corporations?
#
# Research complete!
# Writer agent creating content for: What are the latest breakthroughts in implementing AI in big corporations?
#
# Content creation complete!
#
# ===== RESEARCH OUTPUT =====
# # OVERVIEW
# In recent years, big corporations have been increasingly adopting artificial intelligence (AI) technologies to enhance productivity, improve decision-making processes, and gain a competitive edge. Several breakthroughs have been made in implementing AI in big corporations, including advancements in natural language processing, machine learning algorithms, and AI-driven automation.
#
# # KEY POINTS
# 1. Natural Language Processing (NLP) advancements have allowed big corporations to leverage AI for tasks such as sentiment analysis, chatbots, and language translation.
# 2. Machine learning algorithms have become more sophisticated, enabling big corporations to extract valuable insights from large datasets and optimize business processes.
# 3. AI-driven automation has revolutionized how big corporations streamline operations, reduce costs, and increase efficiency.
# 4. Continuous advancements in AI technologies are enabling big corporations to personalize customer experiences, improve cybersecurity measures, and forecast market trends more accurately.
#
# # DETAILS
# - **Advancements in Natural Language Processing (NLP):** Big corporations are increasingly utilizing AI-powered NLP tools to analyze unstructured data, extract insights from customer feedback, and automate customer service interactions. Breakthroughs in NLP models such as BERT (Bidirectional Encoder Representations from Transformers) have improved language understanding capabilities, enabling more accurate sentiment analysis and chatbot interactions.
#
# - **Sophisticated Machine Learning Algorithms:** Big corporations are leveraging advanced machine learning algorithms such as deep learning and reinforcement learning to develop predictive models, optimize supply chain operations, and enhance decision-making processes. These algorithms enable corporations to analyze complex datasets, uncover patterns, and make data-driven decisions with greater accuracy.
#
# - **AI-Driven Automation:** The adoption of robotic process automation (RPA) and AI-powered automation tools has enabled big corporations to automate repetitive tasks, streamline workflows, and reduce human error. By implementing AI-driven automation, corporations can improve operational efficiency, cut costs, and reallocate resources to more strategic initiatives.
#
# - **Personalized Customer Experiences:** AI technologies like recommendation engines, predictive analytics, and customer segmentation algorithms are helping big corporations deliver personalized products and services to customers. By analyzing customer data in real-time, corporations can tailor marketing campaigns, optimize pricing strategies, and enhance customer engagement.
#
# - **Improved Cybersecurity Measures:** AI-powered cybersecurity solutions are increasingly being adopted by big corporations to detect and respond to cyber threats more effectively. By leveraging AI algorithms for anomaly detection, threat intelligence, and behavioral analytics, corporations can strengthen their cybersecurity posture and safeguard sensitive data from potential breaches.
#
# - **Enhanced Market Forecasting:** Big corporations are utilizing AI technologies to analyze market trends, predict consumer behavior, and make strategic business decisions. By incorporating machine learning models into their forecasting processes, corporations can gain insights into market dynamics, identify emerging opportunities, and stay ahead of competition in a rapidly evolving business landscape.
#
# ===== FINAL CONTENT =====
# **Title: The AI Revolution in Big Corporations: Latest Breakthroughs and Innovations**
#
# **Introduction:**
# In the ever-evolving landscape of technology, artificial intelligence (AI) has emerged as a game-changer for big corporations seeking to drive innovation, boost efficiency, and stay ahead of the competition. With breakthroughs in natural language processing, machine learning algorithms, and AI-driven automation, big corporations are harnessing the power of AI to transform their operations and enhance decision-making processes. Let's delve into the latest advancements in implementing AI in big corporations and how these breakthroughs are reshaping the business world.
#
# **Body:**
#
# **Advancements in Natural Language Processing (NLP):**
# One of the key breakthroughs in implementing AI in big corporations is the advancements in Natural Language Processing (NLP). By leveraging AI-powered NLP tools like BERT, corporations can now analyze unstructured data, automate customer service interactions, and gain valuable insights from customer feedback. This has revolutionized how corporations understand customer sentiments, improve chatbot interactions, and enhance language translation capabilities.
#
# **Sophisticated Machine Learning Algorithms:**
# The sophistication of machine learning algorithms has empowered big corporations to extract meaningful insights from vast datasets, optimize business processes, and make data-driven decisions with precision. With advanced algorithms such as deep learning and reinforcement learning, corporations can uncover patterns, predict outcomes, and enhance supply chain operations. This has enabled corporations to enhance decision-making processes and drive efficiency across various business functions.
#
# **AI-Driven Automation:**
# AI-driven automation has become a cornerstone for big corporations looking to streamline operations, reduce costs, and improve efficiency. By adopting robotic process automation (RPA) and AI-powered automation tools, corporations can automate repetitive tasks, streamline workflows, and minimize human errors. This not only enhances operational efficiency but also allows corporations to reallocate resources to strategic initiatives, driving overall business growth.
#
# **Personalized Customer Experiences:**
# In the era of personalization, AI technologies are enabling big corporations to deliver tailored customer experiences through recommendation engines, predictive analytics, and customer segmentation algorithms. By analyzing real-time customer data, corporations can customize marketing campaigns, optimize pricing strategies, and enhance customer engagement. This level of personalization not only boosts customer satisfaction but also drives revenue growth and brand loyalty.
#
# **Improved Cybersecurity Measures:**
# With the increasing threat of cyber attacks, big corporations are turning to AI-powered cybersecurity solutions to bolster their defenses. By leveraging AI algorithms for anomaly detection, threat intelligence, and behavioral analytics, corporations can detect and respond to cyber threats more effectively. This proactive approach to cybersecurity helps corporations safeguard sensitive data, mitigate risks, and maintain trust with customers and stakeholders.
#
# **Enhanced Market Forecasting:**
# AI technologies are empowering big corporations to analyze market trends, predict consumer behavior, and make informed business decisions. By incorporating machine learning models into their forecasting processes, corporations can gain valuable insights into market dynamics, identify emerging opportunities, and stay competitive in a rapidly changing business environment. This enables corporations to adapt to market trends, optimize strategies, and drive sustainable growth.
#
# **Conclusion:**
# The latest breakthroughs in implementing AI in big corporations are reshaping the way businesses operate, make decisions, and engage with customers. From advancements in natural language processing to sophisticated machine learning algorithms and AI-driven automation, big corporations are leveraging AI technologies to drive innovation, enhance efficiency, and gain a competitive edge in the market. As AI continues to evolve, big corporations must embrace these breakthroughs to stay agile, responsive, and successful in an increasingly digital world.

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables and initialize OpenAI client
load_dotenv()
client = OpenAI(
    base_url="https://openai.vocareum.com/v1",
    api_key=os.getenv("OPENAI_API_KEY")
)

def call_openai(system_prompt, user_prompt, temp, model="gpt-3.5-turbo"):
    """Simple wrapper for OpenAI API calls"""
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=temp
    )
    return response.choices[0].message.content


# ========== AGENTS ==========

def feedstock_analyst_agent(feedstock_name):
    """Analyzes the hydrocarbon feedstock composition and quality"""
    system_prompt = """You are a chemical process expert. Given a hydrocarbon feedstock, analyze its composition, typical contaminants, boiling point ranges, and general quality."""
    user_prompt = f"Analyze the hydrocarbon feedstock named '{feedstock_name}'."
    print(f"🔬 Feedstock analyst working on: {feedstock_name}")
    return call_openai(system_prompt, user_prompt, temp=0.4)


def distillation_planner_agent(feedstock_analysis):
    """Plans how the feedstock will be separated in a distillation tower"""
    system_prompt = """You are a refinery planner specializing in distillation processes. Based on feedstock composition, recommend a distillation cut strategy (e.g., naphtha, kerosene, diesel, residue) with approximate percentages."""
    user_prompt = f"Plan distillation for this feedstock:\n\n{feedstock_analysis}"
    print(f"⚗️  Distillation planner analyzing feedstock...")
    return call_openai(system_prompt, user_prompt, temp=0.4)


def market_analyst_agent(product_list):
    """Provides market outlook for refined products"""
    system_prompt = """You are an energy market analyst. Given a list of refined products, provide a short-term market outlook (e.g., demand trends, price forecast, regional considerations)."""
    user_prompt = f"Analyze market outlook for the following products:\n\n{product_list}"
    print(f"📈 Market analyst reviewing products...")
    return call_openai(system_prompt, user_prompt, temp=0.5)


def production_optimizer_agent(distillation_plan, market_data):
    """Optimizes the production plan based on technical and market data"""
    system_prompt = """You are a refinery operations strategist. Based on a distillation plan and market data, recommend the most profitable product mix. Justify your decision."""
    user_prompt = f"""Distillation Plan:\n{distillation_plan}\n\nMarket Outlook:\n{market_data}"""
    print(f"🛠️  Production optimizer creating production plan...")
    return call_openai(system_prompt, user_prompt, temp=0.3)


# ========== WORKFLOW ==========

def run_refinery_planning_workflow(feedstock_name):
    print(f"\n🚀 Starting refinery optimization workflow for: '{feedstock_name}'\n")

    # Step 1: Feedstock analysis
    feedstock_report = feedstock_analyst_agent(feedstock_name)
    print("\n=== FEEDSTOCK ANALYSIS ===")
    print(feedstock_report)

    # Step 2: Distillation plan
    distillation_plan = distillation_planner_agent(feedstock_report)
    print("\n=== DISTILLATION STRATEGY ===")
    print(distillation_plan)

    # Step 3: Market analysis
    product_list = "naphtha, kerosene, diesel, gas oil, residue"  # could be parsed from plan
    market_insights = market_analyst_agent(product_list)
    print("\n=== MARKET OUTLOOK ===")
    print(market_insights)

    # Step 4: Production optimization
    optimized_plan = production_optimizer_agent(distillation_plan, market_insights)
    print("\n=== OPTIMIZED PRODUCTION PLAN ===")
    print(optimized_plan)

    return {
        "feedstock": feedstock_report,
        "distillation": distillation_plan,
        "market": market_insights,
        "optimized_plan": optimized_plan
    }


# ========== ENTRY POINT ==========

if __name__ == "__main__":
    feedstock_name = "West Texas Intermediate (WTI) crude oil"
    run_refinery_planning_workflow(feedstock_name)
# Out:
# 🚀 Starting refinery optimization workflow for: 'West Texas Intermediate (WTI) crude oil'
#
# 🔬 Feedstock analyst working on: West Texas Intermediate (WTI) crude oil
#
# === FEEDSTOCK ANALYSIS ===
# West Texas Intermediate (WTI) crude oil is a high-quality light sweet crude oil that is commonly used as a benchmark in oil pricing. Here is an analysis of its composition, typical contaminants, boiling point ranges, and general quality:
#
# Composition:
# - WTI crude oil is primarily composed of hydrocarbons, with a high proportion of light hydrocarbons such as alkanes, cycloalkanes, and aromatics.
# - It typically has a low sulfur content, making it a "sweet" crude oil.
# - The API gravity of WTI crude oil is usually around 39-42, indicating that it is a light crude oil.
#
# Typical contaminants:
# - WTI crude oil may contain trace amounts of sulfur compounds, nitrogen compounds, and metals such as nickel and vanadium.
# - Contaminants such as water and sediment may also be present in small quantities.
#
# Boiling point ranges:
# - The boiling point range of WTI crude oil is typically between 100°C to 400°C, with different fractions boiling off at different temperatures.
# - Lighter fractions such as gasoline and diesel boil off at lower temperatures, while heavier fractions such as fuel oil and bitumen boil off at higher temperatures.
#
# General quality:
# - WTI crude oil is considered a high-quality crude oil due to its low sulfur content, high API gravity, and relatively low levels of contaminants.
# - It is highly sought after by refiners for its ease of processing into high-value products such as gasoline, diesel, and jet fuel.
# - WTI crude oil is known for its stability and consistency, making it a reliable benchmark for global oil pricing.
#
# Overall, WTI crude oil is a high-quality feedstock that is prized for its favorable composition, low sulfur content, and consistent quality, making it a preferred choice for refining into valuable petroleum products.
# ⚗️  Distillation planner analyzing feedstock...
#
# === DISTILLATION STRATEGY ===
# Based on the composition and characteristics of WTI crude oil, a typical distillation cut strategy could be as follows:
#
# 1. Light Naphtha: 15-20%
#    - This fraction can include light hydrocarbons such as alkanes and aromatics that boil off at lower temperatures. It is commonly used as a feedstock for petrochemical processes or blending into gasoline.
#
# 2. Heavy Naphtha / Kerosene: 15-20%
#    - This fraction can consist of slightly heavier hydrocarbons that boil off at slightly higher temperatures. It can be further processed into kerosene or used as a blending component for jet fuel.
#
# 3. Diesel: 25-30%
#    - The diesel fraction can include mid-range hydrocarbons suitable for diesel fuel production. It is an important product for various industries, including transportation and heating.
#
# 4. Gas Oil: 20-25%
#    - This fraction comprises heavier hydrocarbons that can be further processed into lubricating oils, heating oils, or as a feedstock for secondary processing units.
#
# 5. Residue: 10-15%
#    - The residue fraction contains the heaviest hydrocarbons that have not been vaporized in the distillation process. It can be used for bitumen production, fuel oil, or as a feedstock for further processing units like cokers or hydrocrackers.
#
# This distillation cut strategy aims to maximize the yield of valuable products such as gasoline, diesel, and jet fuel while efficiently processing the various components of WTI crude oil based on their boiling points and properties.
# 📈 Market analyst reviewing products...
#
# === MARKET OUTLOOK ===
# 1. Naphtha: Naphtha is commonly used as a feedstock in the petrochemical industry for producing plastics and other chemicals. The demand for naphtha is expected to remain stable in the short term, supported by the recovery in industrial activities and the increasing demand for plastics. However, the market could face some pressure from the shift towards more sustainable alternatives in the long run. Prices are likely to be influenced by crude oil prices and global petrochemical demand.
#
# 2. Kerosene: The demand for kerosene has been declining in recent years due to the shift towards cleaner energy sources and the decrease in aviation activities amid the COVID-19 pandemic. In the short term, the market outlook for kerosene remains subdued, with limited upside potential in demand. Prices are expected to remain under pressure due to oversupply and weak demand, especially in regions heavily dependent on aviation.
#
# 3. Diesel: Diesel is a key fuel for transportation and industrial sectors, and its demand is closely linked to economic activities. With the gradual recovery of global economies post-pandemic, the demand for diesel is expected to increase in the short term. The market outlook for diesel is relatively positive, supported by the rebound in industrial production and transportation sectors. Prices are likely to be influenced by factors such as crude oil prices, supply-demand dynamics, and regulatory policies.
#
# 4. Gas oil: Gas oil, also known as middle distillates, is used for heating, transportation, and industrial purposes. The market outlook for gas oil is expected to be stable in the short term, driven by the recovery in economic activities and increasing demand for heating fuels during the winter season. Prices may experience some volatility due to geopolitical tensions, supply disruptions, and changes in global oil demand.
#
# 5. Residue: Residue, also known as fuel oil, is a heavy and viscous product used in power generation and marine bunkering. The market outlook for residue remains challenging in the short term due to the global push towards cleaner fuels and the implementation of stricter environmental regulations. Demand for residue is expected to decline further as industries and shipping companies switch to cleaner alternatives such as LNG and low-sulfur fuels. Prices are likely to remain under pressure, reflecting the oversupply situation and weak demand for residue.
# 🛠️  Production optimizer creating production plan...
#
# === OPTIMIZED PRODUCTION PLAN ===
# Based on the distillation plan and market outlook provided, the most profitable product mix for the refinery would be to focus on maximizing the production of diesel and gas oil, while optimizing the production of light naphtha for petrochemical feedstock.
#
# Here's the justification for this recommendation:
#
# 1. Diesel: The market outlook for diesel is relatively positive, with increasing demand expected in the short term due to the rebound in industrial production and transportation sectors post-pandemic. Diesel is a key fuel for various industries and transportation, making it a lucrative product to focus on for maximizing profitability.
#
# 2. Gas Oil: Gas oil, being used for heating, transportation, and industrial purposes, has a stable market outlook in the short term. The recovery in economic activities and the increasing demand for heating fuels during the winter season will support the demand for gas oil. By optimizing the production of gas oil, the refinery can capitalize on the stable market conditions and potentially benefit from the increasing demand.
#
# 3. Light Naphtha: While the demand for naphtha is expected to remain stable in the short term, it is commonly used as a feedstock in the petrochemical industry for producing plastics and other chemicals. By producing light naphtha as a byproduct and optimizing its production for petrochemical feedstock, the refinery can tap into the demand from the petrochemical sector and enhance its overall profitability.
#
# By focusing on maximizing the production of diesel, gas oil, and optimizing the production of light naphtha, the refinery can align its product mix with the market demand and potential profitability opportunities in the short term. This strategy takes into account the current market dynamics and aims to leverage the strengths of the refinery's distillation plan to generate the most profitable product mix.
