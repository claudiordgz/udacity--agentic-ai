# %%
"""
Program Management Knowledge Agent

This program demonstrates two approaches to answering program management questions:
1. Using hardcoded knowledge
2. Using an LLM API

Complete the TODOs to build your knowledge agent.
"""

from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    base_url="https://openai.vocareum.com/v1", 
    api_key=openai_api_key
)


def get_hardcoded_answer(question):
    """
    Return answers to program management questions using hardcoded knowledge.
    
    Args:
        question (str): The question about program management
        
    Returns:
        str: The answer to the question
    """
    q = question.lower()

    if "gantt" in q:
        return "A Gantt chart is a visual tool that shows the start and finish dates of tasks in a project."
    elif "agile" in q:
        return "Agile is an iterative project management methodology that emphasizes flexibility and customer feedback."
    elif "sprint" in q:
        return "A sprint is a fixed-length iteration (usually 1-4 weeks) during which a team completes a set of work."
    elif "critical path" in q:
        return "The critical path is the sequence of dependent tasks that determine the shortest time to complete the project."
    elif "milestone" in q:
        return "A milestone is a significant event or checkpoint in the progress of a project."
    else:
        return "Sorry, I don't have a hardcoded answer for that. Try asking the LLM!"

def get_llm_answer(question):
    """
    Get answers to program management questions using an LLM API.
    
    Args:
        question (str): The question about program management
        
    Returns:
        str: The answer from the LLM
    """
    if not openai_api_key:
        return "OpenAI API key not found. Please check your .env file."

    try:
        response = client.chat.completions.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": "You are a program management expert."},
                {"role": "user", "content": question}
            ],
            max_tokens=150
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error calling LLM: {e}"

def compare_answers(question):
    """Compare answers from both approaches for a given question."""
    print(f"\nQuestion: {question}")
    print("-" * 50)
    
    hardcoded = get_hardcoded_answer(question)
    print(f"Hardcoded Answer:\n{hardcoded}")
    print("-" * 50)

    llm = get_llm_answer(question)
    print(f"LLM Answer:\n{llm}")
    print("=" * 50)

# Run the demo
if __name__ == "__main__":
    print("PROGRAM MANAGEMENT KNOWLEDGE AGENT DEMO")
    print("=" * 50)
    
    questions = [
        "What is a Gantt chart?",
        "How does Agile methodology work?",
        "What is a sprint?",
        "Can you explain the critical path?",
        "What are milestones in a project?",
        "How do you calculate project ROI?",
        "What is risk management in program management?"
    ]

    for q in questions:
        compare_answers(q)
# Out:
# PROGRAM MANAGEMENT KNOWLEDGE AGENT DEMO
# ==================================================
#
# Question: What is a Gantt chart?
# --------------------------------------------------
# Hardcoded Answer:
# A Gantt chart is a visual tool that shows the start and finish dates of tasks in a project.
# --------------------------------------------------
# LLM Answer:
# A Gantt chart is a type of bar chart that illustrates a project schedule. It is a graphical depiction of a project schedule that allows project managers to break the project into tasks, each of which is displayed on a timeline.
#
# Key features of a Gantt chart include the start date, end date, duration of each task, and their dependencies (how tasks are related to each other). This visual representation helps in planning, scheduling, coordinating, and tracking specific tasks in a project, thereby assisting in effective project management.
# ==================================================
#
# Question: How does Agile methodology work?
# --------------------------------------------------
# Hardcoded Answer:
# Agile is an iterative project management methodology that emphasizes flexibility and customer feedback.
# --------------------------------------------------
# LLM Answer:
# The Agile methodology is an approach to project management, widely used in software development, that emphasizes flexibility, collaboration, and customer satisfaction. Below are the key principles of how this methodology works:
#
# 1. Small, Iterative Cycles: Agile projects are broken down into small parts called iterations or sprints. Each sprint lasts typically between one to four weeks, and by the end, a functional section of the project should be completed, testable, and ready for review by the customer.
#
# 2. Collaboration and Communication: Agile promotes close collaboration between cross-functional teams and stakeholders. Regular meetings called daily stand-ups or Scrum meetings are held to check on the progress, discuss issues, and plan work for the next day.
#
# 3. Feedback and Adaptability:
# ==================================================
#
# Question: What is a sprint?
# --------------------------------------------------
# Hardcoded Answer:
# A sprint is a fixed-length iteration (usually 1-4 weeks) during which a team completes a set of work.
# --------------------------------------------------
# LLM Answer:
# A sprint, in project management terms, is a set time period within the Scrum framework where specific work has to be completed and made ready for review. Sprints usually last between one week to one month and are a key part of Agile development methodologies, where projects are divided into smaller, manageable units of work. The goal of each sprint is to produce a potentially shippable product increment.
# ==================================================
#
# Question: Can you explain the critical path?
# --------------------------------------------------
# Hardcoded Answer:
# The critical path is the sequence of dependent tasks that determine the shortest time to complete the project.
# --------------------------------------------------
# LLM Answer:
# Yes, of course!
#
# The critical path in project management refers to the longest sequence of tasks in a project that must be completed on time in order for the project to finish on its due date. In other words, it's the sequence of tasks that determines the shortest possible duration of the project.
#
# Several important points are associated with the critical path:
#
# 1. Any delay in the tasks on the critical path would delay the project's completion.
# 2. Each task on the critical path is known as a critical task/activity.
# 3. There is zero float or slack time in the critical path, meaning these tasks cannot be postponed without affecting the project's finish time.
#
# Therefore, effective management of critical path activities is crucial for on-time project completion. Not every activity
# ==================================================
#
# Question: What are milestones in a project?
# --------------------------------------------------
# Hardcoded Answer:
# A milestone is a significant event or checkpoint in the progress of a project.
# --------------------------------------------------
# LLM Answer:
# Milestones in a project are specific goals or events that mark significant progress or phases in the project. They are used as reference points to monitor the project's advancement and ensure that it remains on schedule. Milestones can represent anything from the completion of a significant task or activity, a decision point, a deadline, or the achievement of a particular result or outcome. They are crucial in project planning and management because they identify the key deliverables and help to maintain focus on what's important.
# ==================================================
#
# Question: How do you calculate project ROI?
# --------------------------------------------------
# Hardcoded Answer:
# Sorry, I don't have a hardcoded answer for that. Try asking the LLM!
# --------------------------------------------------
# LLM Answer:
# Project Return on Investment (ROI) is calculated by using the following formula:
#
# ROI = (Net Profit / Cost of the Project) * 100%
#
# Here's a step-by-step guide:
#
# 1. Calculate Net Profit: This is done by subtracting the cost of the project from the gains of the project. The cost includes all the expenses incurred during the implementation and management of the project. The gains refer to the revenue earned from the project.
#
# 2. Divide the Net Profit by the Cost of the Project: After determining the net profit, the next step is to divide it by the cost of the project.
#
# 3. Multiply the Result by 100: To convert the result into percentage, multiply it by 100. The final number represents the ROI
# ==================================================
#
# Question: What is risk management in program management?
# --------------------------------------------------
# Hardcoded Answer:
# Sorry, I don't have a hardcoded answer for that. Try asking the LLM!
# --------------------------------------------------
# LLM Answer:
# Risk Management in program management is the process of identifying, analyzing, and responding to risk factors throughout the life of a program. This involves managing the probability and the impact of potential risks. The goal of risk management is to ensure that risks are adequately addressed and mitigated to prevent them from adversely impacting the program's objectives and deliverables. It includes steps such as risk identification, risk assessment, risk response planning, and risk monitoring and control. This systematic process helps in making informed decisions and reducing uncertainties in the program.
# ==================================================
